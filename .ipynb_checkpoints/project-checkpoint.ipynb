# %% [markdown]
# ### Äriline eesmärk
#  - Ennustada tudengite ajalise panuse, kirjutatud ja kustutatud ridade arvu ning commit messagite järgi tudengi tulemust
#  - Teha selgeks, milliseid erinevaid tudengi tüübid eksisteerivad ja kuidas tudengid on nende tüüpide vahel jaotunud, et saaks pakkuda tudengitele personaalsemat tagasisidet / ülesandeid.
#
# ### Analüüsi eesmärk
# - Pideva muutuja points ennustamine
# - Andmestiku sisemise struktuuri kirjeldamine

# %% [markdown]
# ## Andmete teisendamine
# 1) Tuleb exportida andmed rakendusest gtm csv vormingusse.
# 2) Tuleb exportida moodle "Grades" andmed csv vormingusse.
# 3) Jooksutada programmi gtm-moodle-converter (https://github.com/kilpkonn/gtm-moodle-converter)

# %% [markdown]
# ## Andmete struktuur
#
# - **hash**: Hashed user identifier. Can be used to group data by user.
# - **path**: Edited file path or program name. For files this is either a complete path or
#   path beginning. For files this usually corresponds to task folder.
#   _(Amount of files grouped can be seen in `files` field)_
# - **is_app**: Identifier whether the time is recorded running program or editing file.
# - **points**: Moodle (undefended) points.
# - **style_points**: Style points. Typically either 0 or 1.
# - **time**: Time recorded for `path` in seconds.
# - **lines_added**: Amount of lines written in `path` according to git diff. Copy pastes without
# time data are considered 0.
# - **lines_removed**: Amount of lines deleted in `path` according to git diff. Deletes without
# any time spent are considered 0.
# - **files**: Amount of files grouped for `path`
# - **message**: Commit message
# - **timestamp**: UNIX timestamp in seconds

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.decomposition import PCA

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split, cross_val_score

# %%
df = pd.read_csv('./iti0202-2021.csv')
df.head(3)
# Out:
#                                        hash  \
# 0  26abbf77e39340038a011fc45ef70f8bb004a92b
# 1  cffaf3750341cee73be546d2d15e3a9bec8c5c5d
# 2  a4076a2bcf120779015e2aa34f816dea364e0c57
#
#                                          path  is_app  points  style_points  \
# 0                           ex/ex02webbrowser   False    0.00           0.0
# 1  .gtm/application: morsefilescontroller.app    True    0.00           0.0
# 2                           ex/ex05mysticorbs   False   13.19           1.0
#
#    time  lines_added  lines_removed  files message   timestamp
# 0  2253          146             53      2    ex02  1612735807
# 1    10            0              0      1    ex06  1615305058
# 2   561            0              0      2   input  1614877930

# %%
df.describe()
# Out:
#              points  style_points          time   lines_added  lines_removed  \
# count  17788.000000  17788.000000  17788.000000  17788.000000   17788.000000
# mean       3.289470      0.298460    678.141837     20.697605       8.944401
# std        6.027127      0.470199   2469.384224    121.626285     685.670188
# min        0.000000      0.000000      2.000000      0.000000       0.000000
# 25%        0.000000      0.000000     43.000000      0.000000       0.000000
# 50%        0.000000      0.000000    127.000000      0.000000       0.000000
# 75%        3.500000      1.000000    420.000000      6.000000       2.000000
# max       92.870000     14.000000  73277.000000   7790.000000   91389.000000
#
#               files     timestamp
# count  17788.000000  1.778800e+04
# mean       1.865696  1.615239e+09
# std        2.775822  2.066952e+06
# min        1.000000  1.611666e+09
# 25%        1.000000  1.613597e+09
# 50%        1.000000  1.614717e+09
# ...

# %% [markdown]
# ## Pideva muutuja "points" ennustamine
# Vaatlen andmete inimene, ülesanne gruppe ning vabanen muutujast, style_style points, sest see on aine ülesehituse tõttu väga tugevalt seotud punktidega ning ei ole reaalselt meile kasulik.
# Selle asemel kasutan style_mean muutujat, mis iseloomustab, kui hästi stiilinõuetele vastab arenduse ajal tudengi kood.

# %%
person_task_df = df.copy()
person_task_df = person_task_df[person_task_df['is_app'] == False]
person_task_df['message_len'] = person_task_df['message'].apply(lambda x: len(str(x)))
person_task_df = person_task_df.groupby(['hash', 'path']).aggregate(
          points=('points', np.max), # Only max counts in real life
          style_mean=('style_points', np.mean), # Only max gives unrealistical results
          time=('time', np.sum),  # Total time per task
          time_mean=('time', np.mean),  # Average time per commit
          time_median=('time', np.median),  # Element-wise average time per commit
          lines_added=('lines_added', np.sum),  # Total lines added 
          lines_removed=('lines_removed', np.sum),  # Total lines removed
          files=('files', np.max),  # Files in solution
          timestamp_mean=('timestamp', np.mean),  # Average timestamp
          timestamp_median=('timestamp', np.median),  # Element-wise average timestamp
          timestamp_max=('timestamp', np.max),  # Last commit time
          timestamp_min=('timestamp', np.min),  # First commit time
          message_len=('message_len', np.mean)  # Average commit message length
         )
person_task_df.reset_index()
person_task_df
# Out:
#                                                                points  \
# hash                                     path
# 0163f19bf716a3aeda720deecfa0afb6dab53d87 ex/ex02webbrowser        0.0
#                                          ex/ex03bookshelf         0.0
#                                          ex/ex04socialnetwork     0.0
#                                          ex/ex05mysticorbs        7.9
#                                          ex/ex06files             0.0
# ...                                                               ...
# f8ce8c5a768ee94c031b0fce1a62e295688bc86b pr/pr03ring              0.0
#                                          pr/pr04stock             0.0
#                                          pr/pr06shelter           0.0
#                                          tk/tk0                   5.0
#                                          tk/tk1                   5.0
#
#                                                                style_mean  \
# ...

# %%
task_df= df.copy()
task_df = task_df[task_df['is_app'] == False]
task_df['message_len'] = task_df['message'].apply(lambda x: len(str(x)))
task_df = task_df.groupby('path').aggregate(
          points=('points', np.max),
          style_mean=('style_points', np.max), 
          time=('time', np.mean),  # Average person time
          time_mean=('time', np.mean),
          time_median=('time', np.median),
          lines_added=('lines_added', np.mean),  # Per person
          lines_removed=('lines_removed', np.mean),  # Per person 
          files=('files', np.mean),
          timestamp_mean=('timestamp', np.mean),
          timestamp_median=('timestamp', np.median),
          timestamp_max=('timestamp', np.max),
          timestamp_min=('timestamp', np.min),
          message_len=('message_len', np.mean) 
         )
task_df.reset_index()
task_df
# Out:
#                         points  style_mean        time   time_mean  \
# path
# .gitignore                 0.0         0.0  141.888889  141.888889
# .gtm/1613925862.event      0.0         0.0    6.000000    6.000000
# .gtm/1617781072.event      0.0         0.0    8.000000    8.000000
# .idea/iti0202-2021.iml     0.0         0.0  240.000000  240.000000
# .idea/modules.xml          0.0         0.0  126.428571  126.428571
# ...                        ...         ...         ...         ...
# tk/tk2                     5.0         1.0  466.593074  466.593074
# tk/tk3                     5.0         1.0  544.696970  544.696970
# tk/tk33                    0.0         0.0  155.000000  155.000000
# tk/tk4                     5.0         1.0  581.151515  581.151515
# tournament.txt             0.0         0.0   10.000000   10.000000
#
#                         time_median  lines_added  lines_removed     files  \
# path
# ...

# %%
# person_task_df['timestamp'] = person_task_df['timestamp'] - task_df['timestamp']
# person_task_df['timestamp_max'] = person_task_df['timestamp_max'] - task_df['timestamp_max']
# person_task_df['duration'] = (person_task_df['timestamp_max'] - person_task_df['timestamp_min']) / \
#                                 (task_df['timestamp_max'] - task_df['timestamp_min']) / task_df['points']
person_task_df['points'] = person_task_df['points'] / task_df['points']
person_task_df['style_mean'] = person_task_df['style_mean'] / task_df['style_mean']
person_task_df['time'] = person_task_df['time'] / task_df['time'] / task_df['points']
person_task_df['time_mean'] = person_task_df['time_mean'] / task_df['time_mean'] / task_df['points']
person_task_df['time_median'] = person_task_df['time_median'] / task_df['time_median'] / task_df['points']
person_task_df['lines_added'] = person_task_df['lines_added'] / task_df['lines_added'] / task_df['points']
person_task_df['lines_removed'] = person_task_df['lines_removed'] / task_df['lines_removed'] / task_df['points']
person_task_df['files'] = person_task_df['files'] / task_df['files'] / task_df['points']
person_task_df['timestamp_mean'] = person_task_df['timestamp_mean'] - task_df['timestamp_mean']
person_task_df['timestamp_median'] = person_task_df['timestamp_median'] - task_df['timestamp_median']
person_task_df['timestamp_min'] = person_task_df['timestamp_min'] - task_df['timestamp_min']
person_task_df['timestamp_max'] = person_task_df['timestamp_max'] - task_df['timestamp_max']
person_task_df['message_len'] = person_task_df['message_len'] / task_df['message_len']

# person_task_df = person_task_df.drop(columns=['timestamp_max', 'timestamp'], axis=1)
person_task_df = person_task_df.dropna()
person_task_df
# Out:
#                                                                   points  \
# hash                                     path
# 0163f19bf716a3aeda720deecfa0afb6dab53d87 ex/ex03bookshelf       0.000000
#                                          ex/ex05mysticorbs      0.526667
# 03062dc1bddd1c4f7433fefa74079520759db3ab ex/ex00hello           1.000000
#                                          ex/ex01idcode          1.000000
#                                          ex/ex03bookshelf       0.890000
# ...                                                                  ...
# f8ce8c5a768ee94c031b0fce1a62e295688bc86b lx/lx05generics        0.790000
#                                          pr/pr01introduction    1.000000
#                                          pr/pr02datastructures  1.000000
#                                          tk/tk0                 1.000000
#                                          tk/tk1                 1.000000
#
# ...

# %%
sns.pairplot(person_task_df)
plt.show()

# %%
cm = np.corrcoef(person_task_df.T)
sns.set(font_scale=1.5)
# plt.figure(figsize = (20,5))
# hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f',
#                  annot_kws={'size': 11}, yticklabels=person_task_df.columns,
#                  xticklabels=person_task_df.columns, 
#                  cmap=sns.diverging_palette(10, 220, sep=80), linewidths=.5)
km = sns.clustermap(cm, cbar=True, annot=True,fmt='.2f',
                    annot_kws={'size': 8}, yticklabels=person_task_df.columns,
                    xticklabels=person_task_df.columns, 
                    cmap=sns.diverging_palette(10, 220, sep=80))
km.fig.suptitle('Correlation matrix') 
plt.show()

# %% [markdown]
# Selgub, et punktid on kõigi muutujatega väga vähe korreleeruvad peal `style_points` muutuja.
# Viimane on muidugi loogiline, sest punkte ei saa enne kuitsta kui stiili punktid olemas on ja seega
# kui punktid käes, siis tehakse ka stiil korda.
#
# ## Andmete sisemine struktuur
# Et saada aimu andmete sisemisest struktuurist, rakendan andmetele Pea komponent analüüsi

# %%
pca = Pipeline(steps = [('sc', StandardScaler()),
                        ('pca', PCA(n_components=2))])
pca.fit(person_task_df)

pca_frame = pd.DataFrame(pca.named_steps['pca'].components_, columns=person_task_df.columns)
pca_frame.T
# Out:
#                          0         1
# points            0.072395 -0.040574
# style_mean        0.064570  0.019342
# time              0.389633  0.273774
# time_mean         0.291972  0.394896
# time_median       0.247891  0.372737
# lines_added       0.356100  0.037553
# lines_removed     0.301401  0.034828
# files             0.289631  0.353036
# timestamp_mean   -0.379080  0.368526
# timestamp_median -0.352236  0.404953
# timestamp_max    -0.105746  0.122116
# timestamp_min    -0.324534  0.408226
# message_len       0.079155 -0.139764

# %% [markdown]
# ## Punktide ennustamine
# Üritan ennustada tudengi punkte muude parameetrite järgi.
# Kustutan `style_mean` tulba, kuna see annaks ebaause eelise punktide ennustamisel.

# %%
y = person_task_df['points']
X = person_task_df.loc[:, person_task_df.columns != 'points']
X = X.drop('style_mean', axis=1)
# X

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, 
                                                    random_state=1)

# %%
slr = Pipeline([('ss', StandardScaler()), 
                ('lr', LinearRegression())])
slr.fit(X_train, y_train)

for col_name, x_i in sorted(zip(X.columns, slr.named_steps['lr'].coef_), key=lambda x: -abs(x[1])):
    print(f"{col_name:<15} {round(x_i, 4)}")
# Out:
# time_median     -0.0923
# timestamp_max   -0.0679
# timestamp_min   0.0545
# timestamp_median -0.0515
# message_len     0.0489
# time_mean       0.0465
# lines_added     0.0328
# timestamp_mean  0.0306
# time            0.0076
# files           -0.0057
# lines_removed   -0.0013

# %%
scores = cross_val_score(estimator=slr,
                         X=X_train,
                         y=y_train,
                         cv=10,
                         n_jobs=1)
print('CV keskmine R2 täpsus: %.3f' % np.mean(scores), "+/- %.3f" % np.std(scores))
print('Keskmine R2 täpsus treeningandmetel: %.3f' % slr.score(X_train, y_train))
print('Keskmine R2 täpsus testandmetel: %.3f' % slr.score(X_test, y_test))
# Out:
# CV keskmine R2 täpsus: -0.051 +/- 0.248
# Keskmine R2 täpsus treeningandmetel: 0.128
# Keskmine R2 täpsus testandmetel: -1.751

# %%
plr = Pipeline(steps = [('sc', StandardScaler()),
                        ('pf', PolynomialFeatures(degree=2)),
                        ('lr', LinearRegression())])
plr.fit(X_train, y_train)
# for power in plr.named_steps['pf'].powers_:
#     print(f"{power}")
# Out:
# Pipeline(steps=[('sc', StandardScaler()), ('pf', PolynomialFeatures()),
#                 ('lr', LinearRegression())])

# %%
dtr = Pipeline(steps = [('sc', StandardScaler()),
                  ('dt', DecisionTreeRegressor(max_depth=3))])
rfr = Pipeline(steps = [('sc', StandardScaler()),
                  ('rf', RandomForestRegressor(n_estimators=500, criterion='mse'))])

# %%
pipes = {'linear_rtegression': slr,
         'polynomial_regression': plr,
         'decision_tree_regressor': dtr,
         'random_forest_regrossor': rfr}
for name, pipe in pipes.items():
    print(f"{'='*15} [ {name} ] {'='*15}")
    pipe.fit(X_train, y_train)
    scores = cross_val_score(estimator=pipe,
                             X=X_train,
                             y=y_train,
                             cv=10,
                             n_jobs=1)
    print('CV keskmine täpsus: %.3f' % np.mean(scores), "+/- %.3f" % np.std(scores))
    print('Täpsus R2 treeningandmetel: %.3f' % pipe.score(X_train, y_train) )
    print('Täpsus R2 testandmetel: %.3f' % pipe.score(X_test, y_test))
# Out:
# =============== [ linear_rtegression ] ===============
# CV keskmine täpsus: -0.051 +/- 0.248
# Täpsus R2 treeningandmetel: 0.128
# Täpsus R2 testandmetel: -1.751
# =============== [ polynomial_regression ] ===============
# CV keskmine täpsus: -18.762 +/- 35.429
# Täpsus R2 treeningandmetel: 0.488
# Täpsus R2 testandmetel: -298.284
# =============== [ decision_tree_regressor ] ===============
# CV keskmine täpsus: -0.125 +/- 0.270
# Täpsus R2 treeningandmetel: 0.200
# Täpsus R2 testandmetel: -0.173
# =============== [ random_forest_regrossor ] ===============
# CV keskmine täpsus: 0.180 +/- 0.264
# Täpsus R2 treeningandmetel: 0.896
# Täpsus R2 testandmetel: 0.188

# %%
X_time = X['time'].values.reshape(-1, 1)
dtr.fit(X_time, y)
rfr.fit(X_time, y)

plt.scatter(X['time'], y, label="training points", s=5)
X_fit = np.arange(0, 50, 1).reshape(-1, 1)
y_tree_fit = dtr.predict(X_fit)
y_forest_fit = rfr.predict(X_fit)
plt.plot(X_fit, y_tree_fit, label='tree fit', color='black')
plt.plot(X_fit, y_forest_fit, label='forest fit', linestyle='--', color='black')
plt.legend()
plt.xlabel('time')
plt.ylabel('points')
plt.show()

# %%
X_time = X['time'].values.reshape(-1, 1)
slr.fit(X_time, y)
plr.fit(X_time, y)

plt.scatter(X_time, y, label="training points", s=5)
X_fit = np.arange(0, 50, 1).reshape(-1, 1)
y_lin_fit = slr.predict(X_fit)
plt.plot(X_fit, y_lin_fit, label='linear fit', linestyle='--', color='black')
y_pol_fit = plr.predict(X_fit)
plt.plot(X_fit, y_pol_fit, label='polynomial fit', color='black')
plt.legend()
plt.xlabel('time')
plt.ylabel('points')
plt.show()
